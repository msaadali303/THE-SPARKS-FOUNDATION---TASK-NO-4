# %% [markdown]
# # MUHAMMAD SAAD ALI

# %% [markdown]
# ## DATA SCIENCE AND BUSINESS ANALYTICS

# %% [markdown]
# ## TASK NO:3 - EXPLORATORY DATA ANALYSIS - TERRORISM

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin-1')
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Santo Domingo', 'Mexico city', 'Unknown', ..., 'Hungrum',
#        'Ceelka Geelow', 'Kubentog'], dtype=object)

# %%
df['country_txt'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
df['provstate'].unique()
# Out:
# array([nan, 'Federal', 'Tarlac', ..., 'Carlow', 'Western Lakes',
#        'Vidzeme'], dtype=object)

# %%
df['attacktype1_txt'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
df['targtype1_txt'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
df['targsubtype1_txt'].unique()
# Out:
# array(['Named Civilian',
#        'Diplomatic Personnel (outside of embassy, consulate)',
#        'Radio Journalist/Staff/Facility', 'Embassy/Consulate',
#        'Police Building (headquarters, station, school)',
#        'Police Security Forces/Officers', 'Electricity',
#        'Military Recruiting Station/Academy',
#        'Government Building/Facility/Office',
#        'Military Barracks/Base/Headquarters/Checkpost',
#        'Aircraft (not at an airport)', 'Retail/Grocery/Bakery', nan,
#        'Military Personnel (soldiers, troops, officers, forces)',
#        'School/University/Educational Building',
#        'Multinational Corporation', 'Party Office/Facility',
#        'House/Apartment/Residence', 'Race/Ethnicity Identified',
#        'Judge/Attorney/Court',
#        'Police Patrol (including vehicles and convoys)',
#        'Place of Worship', 'Vehicles/Transportation',
#        'Bus (excluding tourists)',
#        'Politician or Political Party Movement/Meeting/Rally',
# ...

# %%
df['gname'].unique()
# Out:
# array(['MANO-D', '23rd of September Communist League', 'Unknown', ...,
#        'Fatoni Warriors', 'Minorities of Metropolitan Attacks',
#        'Baloch Republican Party'], dtype=object)

# %%
df['weapsubtype1_txt'].unique()
# Out:
# array([nan, 'Unknown Explosive Type', 'Unknown Gun Type',
#        'Automatic or Semi-Automatic Rifle',
#        'Molotov Cocktail/Petrol Bomb', 'Gasoline or Alcohol',
#        'Rifle/Shotgun (non-automatic)', 'Arson/Fire', 'Pipe Bomb',
#        'Vehicle', 'Dynamite/TNT', 'Pressure Trigger', 'Time Fuse',
#        'Other Explosive Type', 'Poisoning',
#        'Projectile (rockets, mortars, RPGs, etc.)', 'Handgun',
#        'Letter Bomb', 'Blunt Object', 'Sticky Bomb', 'Grenade',
#        'Knife or Other Sharp Object', 'Landmine', 'Hands, Feet, Fists',
#        'Remote Trigger', 'Rope or Other Strangling Device', 'Explosive',
#        'Unknown Weapon Type', 'Suffocation',
#        'Suicide (carried bodily by human being)', 'Other Gun Type'],
#       dtype=object)

# %%
df.head(1)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
#
# [1 rows x 135 columns]

# %%
df.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'region_txt':'Region',
                   'provstate':'State', 'city':'City', 'attacktype1_txt':'Attack_Type', 'targtype1_txt':'Target_Type',
                   'targsubtype1_txt':'Target_Subtype', 'gname':'Gang_Name', 'weapsubtype1_txt':'Weapon_Type'},inplace=True)

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
Terrorism = df[['Year','Month','Day','City','Country','State','Region','Attack_Type','Target_Type','Target_Subtype',
                'Gang_Name','Weapon_Type']]

# %%
Terrorism.head()
# Out:
#    Year  Month  Day           City             Country    State  \
# 0  1970      7    2  Santo Domingo  Dominican Republic      NaN
# 1  1970      0    0    Mexico city              Mexico  Federal
# 2  1970      1    0        Unknown         Philippines   Tarlac
# 3  1970      1    0         Athens              Greece   Attica
# 4  1970      1    0        Fukouka               Japan  Fukouka
#
#                         Region                     Attack_Type  \
# 0  Central America & Caribbean                   Assassination
# 1                North America     Hostage Taking (Kidnapping)
# 2               Southeast Asia                   Assassination
# 3               Western Europe               Bombing/Explosion
# 4                    East Asia  Facility/Infrastructure Attack
#
#                    Target_Type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
#
# ...

# %%
Terrorism.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# City                435
# Country               0
# State               421
# Region                0
# Attack_Type           0
# Target_Type           0
# Target_Subtype    10373
# Gang_Name             0
# Weapon_Type       20768
# dtype: int64

# %%
Terrorism['City'].fillna(0,inplace=True)
Terrorism['State'].fillna(0,inplace=True)
Terrorism['Target_Subtype'].fillna(0,inplace=True)
Terrorism['Weapon_Type'].fillna(0,inplace=True)

# %%
Terrorism.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# City              0
# Country           0
# State             0
# Region            0
# Attack_Type       0
# Target_Type       0
# Target_Subtype    0
# Gang_Name         0
# Weapon_Type       0
# dtype: int64

# %%
Terrorism.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
Terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   City            181691 non-null  object
#  4   Country         181691 non-null  object
#  5   State           181691 non-null  object
#  6   Region          181691 non-null  object
#  7   Attack_Type     181691 non-null  object
#  8   Target_Type     181691 non-null  object
#  9   Target_Subtype  181691 non-null  object
#  10  Gang_Name       181691 non-null  object
#  11  Weapon_Type     181691 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 16.6+ MB

# %%
Terrorism.shape
# Out:
# (181691, 12)

# %%
Terrorism['City'].value_counts().head(15)
# Out:
# City
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Bogota           984
# Kirkuk           925
# Beirut           918
# Medellin         848
# Name: count, dtype: int64

# %%
Terrorism['Country'].value_counts().head(15)
# Out:
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: count, dtype: int64

# %%
Terrorism['State'].value_counts().head(15)
# Out:
# State
# Baghdad                                7645
# Northern Ireland                       4498
# Unknown                                4290
# Balochistan                            3710
# Saladin                                3411
# Al Anbar                               3299
# Nineveh                                3241
# Sindh                                  3206
# Khyber Pakhtunkhwa                     3084
# Diyala                                 3041
# Lima                                   2615
# Jammu and Kashmir                      2454
# Federally Administered Tribal Areas    2392
# San Salvador                           1923
# Antioquia                              1891
# Name: count, dtype: int64

# %%
Terrorism['Region'].value_counts().head(15)
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Year', data = Terrorism, color = 'teal')
plt.xticks(x = 'Year', rotation = 'vertical')
plt.title('Number of Terrorist each Year')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Region', data = Terrorism , order = Terrorism['Region'].value_counts().index, color = 'teal') 
plt.xticks(x = 'Region',rotation = 'vertical')
plt.title('Most Target Region')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'City', data=Terrorism, order = Terrorism['City'].value_counts().head(10).index, color = 'teal')
plt.xticks(x = 'City',rotation = 'vertical')
plt.title('Most Target City')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Country', data = Terrorism, order = Terrorism['Country'].value_counts().head(10).index, color = 'teal')
plt.title('Most Target Country')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'State', data = Terrorism, order = Terrorism['State'].value_counts().head(10).index, color = 'teal')
plt.title('Most Target State')
plt.show()

# %%
sns.countplot(y = 'Attack_Type', data = Terrorism, order = Terrorism['Attack_Type'].value_counts().index, color = 'teal')
plt.xticks(x = 'Attack_Type', rotation = 90)
plt.title('Most Attack Type')
plt.show()

# %%
sns.countplot(y = 'Weapon_Type', data = Terrorism, order = Terrorism['Weapon_Type'].value_counts().head(10).index, color = 'teal')
plt.xticks(x = 'Weapon_Type', rotation = 'vertical')
plt.title('Most Used Weapon')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Target_Type', data = Terrorism, order = Terrorism['Target_Type'].value_counts().head(10).index, color = 'teal')
plt.xticks(x = 'Target_Type', rotation = 'vertical')
plt.title('Most Target Type')
plt.show()

# %%
Terrorism['Attack_Type'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Region', data = Terrorism, order = Terrorism['Region'].value_counts().head(10).index, hue='Attack_Type')
plt.xticks(x = 'Region', rotation = 'vertical')
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Region VS Attack Type')
plt.show()

# %%
sns.countplot(y = 'Gang_Name', data = Terrorism, order = Terrorism['Gang_Name'].value_counts().head(10).index, color = 'teal')
plt.xticks(x = 'Gang_Name', rotation = 'vertical')
plt.title('Highest Group Terror Attack')
plt.show()

# %%
plt.subplots(figsize = (7,7))
sns.countplot(y = 'Gang_Name', data = Terrorism, order = Terrorism['Gang_Name'].value_counts().head(10).index, hue='Attack_Type')
plt.xticks(x = 'Gang_Name', rotation = 'vertical')
plt.xlabel('Count')
plt.ylabel('Gang Name')
plt.title('Gang VS Attack Type')
plt.show()

# %%
plt.subplots(figsize = (15,8))
sns.countplot(x = 'Year', data = Terrorism, order = Terrorism['Year'].value_counts().head(10).index, hue='Attack_Type')
plt.xticks(x = 'Year', rotation = 'vertical')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Year VS Attack Type')
plt.show()
